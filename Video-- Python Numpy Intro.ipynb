# %%
from IPython.display import YouTubeVideo

YouTubeVideo('8Mpc9ukltVA', width = 800, height=600)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('AAS8yoKuK7M', width = 800, height=600)
